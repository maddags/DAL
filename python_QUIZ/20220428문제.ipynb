# %%
# 색종이 넓이 구하는 문제

#색종이 수 입력
paper_count = int(input("색종이 수는 ????"))

# 각 색종이와 도화지 사이 간격 입력
ru = []
rb = []
lu = []
lb = []

i = 1
while True:
    a,b = input("두 자연수 입력(띄어쓰기로 구분할 것) : ").split()
    a = int(a)
    b = int(b)
    ru.append([a+10,b+10])
    rb.append([a+10,b])
    lu.append([a,b+10])
    lb.append([a,b])
    i += 1
    if i > paper_count:
        break
        
longest_corner = 0
longest_corner_idx = 0
for i,value in enumerate(ru) :
    two_sum = value[0] + value[1]
    if two_sum > longest_corner :
        longest_corner = two_sum
        longest_corner_idx = i

        shortest_corner = 100
shortest_corner_idx = 0
for i,value in enumerate(lb) :
    two_sum2 = value[0] + value[1]
    if two_sum2 < shortest_corner :
        shortest_corner = two_sum2
        shortest_corner_idx = i


print(rb)
print(ru)
print(lb)
print(lu)

biggest_size_paper = ru[longest_corner_idx][0] * ru[longest_corner_idx][1]
smallest_size_paper = lb[shortest_corner_idx][0] * lb[shortest_corner_idx][1]

paper_width = biggest_size_paper - smallest_size_paper
print(ru[longest_corner_idx][0],ru[longest_corner_idx][1])
print(paper_width)
# Out:
# 색종이 수는 ????2
# 두 자연수 입력(띄어쓰기로 구분할 것) : 2 5
# 두 자연수 입력(띄어쓰기로 구분할 것) : 3 7
# [[12, 5], [13, 7]]
# [[12, 15], [13, 17]]
# [[2, 5], [3, 7]]
# [[2, 15], [3, 17]]
# 13 17
# 211

# %%
# 색종이 넓이 구하는 문제

#색종이 수 입력
paper_count = int(input("색종이 수는 ????"))

# 각 색종이와 도화지 사이 간격 입력
ru = []
rb = []
lu = []
lb = []

i = 1
while True:
    a,b = input("두 자연수 입력(띄어쓰기로 구분할 것) : ").split()
    a = int(a)
    b = int(b)
    ru.append([a+10,b+10])
    rb.append([a+10,b])
    lu.append([a,b+10])
    lb.append([a,b])
    i += 1
    if i > paper_count:
        break
longest_height = 0
longest_height_idx = 0
longest_base = 0
longest_base_idx = 0
for i,value in enumerate(ru) :
    first = value[0]
    second = value[1]
    if  second > longest_height :
        longest_height = second
        longest_height_idx = i
    if first > longest_base:
        longest_base = first
        longest_base_idx = i

        
shortest_height = 100
shortest_height_idx = 100
shortest_base = 100
shortest_base_idx = 100
        
for i,value in enumerate(lb) :
    third = value[0]
    fourth = value[1]
    if fourth < shortest_height :
        shortest_height = fourth
        shortest_height_idx = i
    if third < shortest_height :
        shortest_base = third
        shortest_base_idx = i

biggest_size_paper = ru[longest_corner_idx][0] * ru[longest_corner_idx][1]
smallest_size_paper = lb[shortest_corner_idx][0] * lb[shortest_corner_idx][1]
# print(biggest_size_paper)
# print(smallest_size_paper)

paper_width = biggest_size_paper - smallest_size_paper
print(paper_width)
# Out:
# 색종이 수는 ????2
# 두 자연수 입력(띄어쓰기로 구분할 것) : 5 2
# 두 자연수 입력(띄어쓰기로 구분할 것) : 3 7
# 211

# %%
# test_case = int(input("테스트 케이스 개수 : "))
x,y,z = input("세 개의 정수 입력 :").split(" ")
x = int(x)
y = int(y)
z = int(z)

while True:
    R1,R2 = input("R이 선택할 돌 무더기 2개: ").split(" ")
    if R1 == "x" and R2 == "y" :
        x -= 1
        y -= 1
        z += 1
    elif R1 == "x" and R2 == "z" :
        x -= 1
        z -= 1
        y += 1
    elif R1 == "y" and R2 == "z" :
        z -= 1
        y -= 1
        x += 1
    if (x == 0) and (y == 0) :
        print("B의 승리")
        break
    elif (x == 0) and (z == 0) :
        print("B의 승리")
        break
    elif (y == 0 ) and ( z == 0) :
        print("B의 승리")
        break
    
    print(f'돌무더기 개수 : x : {x}, y : {y}, z : {z}')
    B1, B2 = input("B가 선택할 돌 무더기 2개 : ").split(" ")
    if B1 == "x" and B2 == "y" :
        x -= 1
        y -= 1
        z += 1
    elif B1 == "x" and B2 == "z" :
        x -= 1
        z -= 1
        y += 1
    elif B1 == "y" and B2 == "z" :
        z -= 1
        y -= 1
        x += 1

    print(f'돌무더기 개수 : x : {x}, y : {y}, z : {z}')

    if (x == 0) and (y == 0) :
        print("A의 승리")
        break
    elif (x == 0) and (z == 0) :
        print("A의 승리")
        break
    elif (y ==0 ) and ( z == 0) :
        print("A의 승리")
        break
# Out:
# 세 개의 정수 입력 :2 2 2
# R이 선택할 돌 무더기 2개: x y
# 돌무더기 개수 : x : 1, y : 1, z : 3
# B가 선택할 돌 무더기 2개 : y z
# 돌무더기 개수 : x : 2, y : 0, z : 2
# R이 선택할 돌 무더기 2개: x y
# 돌무더기 개수 : x : 1, y : -1, z : 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 8>()
#      29     break
#      31 print(f'돌무더기 개수 : x : {x}, y : {y}, z : {z}')
# ---> 32 B1, B2 = input("B가 선택할 돌 무더기 2개 : ").split(" ")
#      33 if B1 == "x" and B2 == "y" :
#      34     x -= 1
#
# File c:\users\madda\documents\동아리\dal\venvdal\lib\site-packages\ipykernel\kernelbase.py:1161, in Kernel.raw_input(self, prompt)
#    1157 if not self._allow_stdin:
#    1158     raise StdinNotImplementedError(
#    1159         "raw_input was called, but this frontend does not support input requests."
#    1160     )
# -> 1161 return self._input_request(
#    1162     str(prompt),
# ...

# %%
test_case = int(input("테스트 케이스 개수 : "))
x,y,z = input("세 개의 정수 입력 :").split(" ")
x = int(x)
y = int(y)
z = int(z)

for 
    while True:
        R1,R2 = input("R이 선택할 돌 무더기 2개: ").split(" ")
        if R1 == "x" and R2 == "y" :
            x -= 1
            y -= 1
            z += 1
        elif R1 == "x" and R2 == "z" :
            x -= 1
            z -= 1
            y += 1
        elif R1 == "y" and R2 == "z" :
            z -= 1
            y -= 1
            x += 1
        if (x == 0) and (y == 0) :
            print("B의 승리")
            break
        elif (x == 0) and (z == 0) :
            print("B의 승리")
            break
        elif (y == 0 ) and ( z == 0) :
            print("B의 승리")
            break

        print(f'돌무더기 개수 : x : {x}, y : {y}, z : {z}')
        B1, B2 = input("B가 선택할 돌 무더기 2개 : ").split(" ")
        if B1 == "x" and B2 == "y" :
            x -= 1
            y -= 1
            z += 1
        elif B1 == "x" and B2 == "z" :
            x -= 1
            z -= 1
            y += 1
        elif B1 == "y" and B2 == "z" :
            z -= 1
            y -= 1
            x += 1

        print(f'돌무더기 개수 : x : {x}, y : {y}, z : {z}')

        if (x == 0) and (y == 0) :
            print("A의 승리")
            break
        elif (x == 0) and (z == 0) :
            print("A의 승리")
            break
        elif (y ==0 ) and ( z == 0) :
            print("A의 승리")
            break
